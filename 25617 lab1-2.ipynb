# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /'content/gdrive/MyDrive/AIProj'
# Out:
# /content/gdrive/MyDrive/AIProj

# %%
# !git clone "https://github.com/MaybeShewill-CV/lanenet-lane-detection.git"
# Out:
# Cloning into 'lanenet-lane-detection'...
# remote: Enumerating objects: 909, done.
# remote: Total 909 (delta 0), reused 0 (delta 0), pack-reused 909
# Receiving objects: 100% (909/909), 58.43 MiB | 14.31 MiB/s, done.
# Resolving deltas: 100% (507/507), done.
# Updating files: 100% (82/82), done.

# %%
"content/gdrive/MyDrive/AIProj/lane-net-lane-detection/lanenet_model"
# Out:
# 'content/gdrive/MyDrive/AIProj/lane-net-lane-detection/lanenet_model'

# %%
# !python /'content/gdrive/MyDrive/AIProj/lanenet-lane-detection/lanenet_model/lanenet.py'
# Out:
# 2023-03-02 05:23:04.286055: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-02 05:23:05.498473: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-02 05:23:05.498550: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
#Question 1:

a = 10.5
b = 9
c = a - b
print(c)

a1 = 'adnan'
a2 = 'akram'
a3 = a1+a2
print(a3)
# Out:
# 1.5
# adnanakram

# %%
#Question 2:

string1 = "adnan"
string2 = "akram"
string3 = string1 + " " + string2
print(string3)  

string1 = "Hello World  "
string2 = string1 * 6
print(string2)
# Out:
# adnan akram
# Hello World  Hello World  Hello World  Hello World  Hello World  Hello World

# %%
# Assigning literals
a = 5
b = "Hello"
c = 6.99
d = True

# Assigning expressions
x = 5+ 3
y = "Hello" + " " + "World"
z = 10 / 2

# Experimenting with variable names

var1 = 5  # -> Allowed, starts with a letter
_var2 = "Hello"  # -> Allowed, starts with an underscore
VAR6 = "Python"  # -> Allowed, uppercase letters are allowed

# 3var = 3.14 -> Not allowed, starts with a number
# var-4 = True -> Not allowed, contains an invalid character (-)
# va r5 = "World" -> Not allowed, contains spaces

# %%
#Question 4:
def calculate_total(price, tax_rate=0.1, discount=0):
    total = price + price * tax_rate - discount
    return total

result = calculate_total(price=150, tax_rate=0.3, discount=10)
print(result)
# Out:
# 185.0

# %%
#Question 5:
# Expression 1
x = 5
y = 10
z = (x + y) * 2
print(z)  

# Expression 2
name = "adnan"
age = 20
message = "My name is " + name + " and I am " + str(age) + " years old."
print(message)  

# Expression 3
radius = 5
area = 3.14 * radius ** 2
print(area)  

# Expression 4
numbers = [8, 20, 4, 1]
average = sum(numbers) / len(numbers)
print(average)  

# Expression 5
temperature = 25
if temperature > 30:
    print("It's too hot today!")
elif temperature < 10:
    print("It's too cold today!")
else:
    print("The temperature is just right today.")
# Out:
# 30
# My name is adnan and I am 20 years old.
# 78.5
# 8.25
# The temperature is just right today.

# %%
#Question 6: 
# Example 1: Concatenating a string and a numerical value
age = 22
print("I am " + str(age) + " years old.") 

# Example 2: Displaying the result of a numerical expression
x = 9
y = 12
z = x + y
print("The sum of", x, "and", y, "is", z)  
# Example 3: Using f-strings to display the result of an expression
radius = 5
area = 3.14 * radius ** 2
print(f"The area of a circle with radius {radius} is {area:.2f}.")
# Out:
# I am 22 years old.
# The sum of 9 and 12 is 21
# The area of a circle with radius 5 is 78.50.

# %%
#Question 8:3

# Example 1: Adding two numbers input by the user
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
sum = num1 + num2
print("The sum of", num1, "and", num2, "is", sum)

# Example 2: Calculating the area of a rectangle with user input
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))
area = length * width
print("The area of the rectangle is", area)

# Example 3: Converting Fahrenheit to Celsius with user input
fahrenheit = float(input("Enter the temperature in Fahrenheit: "))
celsius = (fahrenheit - 32) * 5 / 9
print("The temperature in Celsius is",celsius)
# Out:
# Enter the first number: 7
# Enter the second number: 6
# The sum of 7 and 6 is 13
# Enter the length of the rectangle: 6
# Enter the width of the rectangle: 9
# The area of the rectangle is 54.0
# Enter the temperature in Fahrenheit: 70
# The temperature in Celsius is 21.11111111111111

# %%
#Question 8:
#Type Error:
x = 5
y = "10"
result = x + y
print(result)

#value error
x = "abc123"
result = int(x)
print(result)

#name error
result = x + y
print(result)
#syntex error
if a = 5:
    print("a is 5")
# Out:
#   File "<ipython-input-8-e308b508f528>", line 17
#     if a = 5:
#          ^
# SyntaxError: invalid syntax
